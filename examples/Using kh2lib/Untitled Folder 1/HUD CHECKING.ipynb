# %%
# Extract original
from kh2lib.kh2lib import kh2lib
import os, json
lib = kh2lib()
if not os.path.isdir("workspace"):
    os.mkdir("workspace")
    
MDLX = "B_EX170_LAST.mdlx"
lib.gamedir = os.environ["KHGAMES_PATH"]
BAR = ""
print(BAR)
assert os.path.isfile(BAR)
lib.editengine.bar_extract(BAR, os.path.join(os.getcwd(), "workspace","finxem"))

# %%
#Extract New
